# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from qdrant_client import QdrantClient

# 從 notebook 所在目錄找 .env（若在 supabase_control 則讀 Erd/.env）
_cwd = Path.cwd()
for _path in [_cwd / "Erd" / ".env", _cwd / ".env"]:
    if _path.exists():
        load_dotenv(_path)
        break
else:
    load_dotenv()

qdrant_client = QdrantClient(
    url=os.getenv("QDRANT_URL", "").strip(),
    api_key=os.getenv("QDRANT_API_KEY", "").strip(),
)
print(qdrant_client.get_collections())
# Out:
# collections=[]

# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

# 指定讀取 .env（與第一個 cell 相同邏輯）
_cwd = Path.cwd()
for _path in [_cwd / "Erd" / ".env", _cwd / ".env"]:
    if _path.exists():
        load_dotenv(_path)
        break
else:
    load_dotenv()

client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY")
)

# 檢查是否已存在
collections = client.get_collections().collections
existing_names = [c.name for c in collections]

if "resume_vectors" not in existing_names:
    client.create_collection(
        collection_name="resume_vectors",
        vectors_config=VectorParams(size=1536, distance=Distance.COSINE)
    )
    print("✅ resume_vectors 建立完成")
else:
    print("⚠️  resume_vectors 已存在")

if "job_vectors" not in existing_names:
    client.create_collection(
        collection_name="job_vectors",
        vectors_config=VectorParams(size=1536, distance=Distance.COSINE)
    )
    print("✅ job_vectors 建立完成")
else:
    print("⚠️  job_vectors 已存在")
# Out:
# ✅ resume_vectors 建立完成
# ✅ job_vectors 建立完成
